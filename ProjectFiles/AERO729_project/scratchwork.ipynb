# %%
from particle import Particle
import numpy as np
from simulationenv import SimulationEnviroment
import matplotlib.pyplot as plt

# %%
s = SimulationEnviroment(
    particles=1000,
    env_height=1,
    env_width=1,
    tolerance=1e-3,
    sigma=1e-4,
    epsilon=0.3
)

# %%
s.run_sim(
    duration=1,
    del_t=0.001
)

# %%
sample_particle = s.particle_list[51]
sample_particle.trajectory

# %%
x, y = zip(*sample_particle.trajectory)
x = np.array(x)
y = np.array(y)

# %%
plt.plot(x, y)
