# %%
from particle import Particle
import numpy as np

# %%
test = Example()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 test = Example()
#
# Cell In[9], line 7, in Example.__init__(self)
#       6 def __init__(self):
# ----> 7     self.var = np.random(3,3)
#
# TypeError: 'module' object is not callable
