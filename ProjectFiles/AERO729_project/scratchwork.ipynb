# %%
from particle import Particle
import numpy as np

# %%
test = Particle(
    initial_pos=np.array([1, 2]),
    initial_velocity=np.array([4, 1]),
    sigma=0.1,
    epsilon=0.01
)

print(test.force)

f = test.calculate_force(
    np.array([1.13, 2.001])
)
print(f)

test.increment_force(f)

print(test.force)

print(test.pos)
# Out:
# [0. 0.]
# [0.60636175 0.00466432]
# [0.60636175 0.00466432]

# %%
test.step(0.01)
# Out:
# array([1.04006064, 2.01000047])

# %%
test.
# Out:
# array([4.00606362, 1.00004664])
