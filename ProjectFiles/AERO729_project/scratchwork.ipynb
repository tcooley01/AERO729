# %%
from particle import Particle
import numpy as np

# %%
test = Particle(
    initial_pos=np.array([1, 2]),
    initial_velocity=np.array([4, 1]),
    sigma=0.1,
    epsilon=0.01
)

print(test.force)

f = test.calculate_force(
    np.array([1.13, 2.001])
)
print(f)

test.increment_force(f)

print(test.force)

print(test.pos)

# %%
test.step(0.01)

# %%
from utilitiies import calculate_box_width

calculate_box_width(tol=1e-5, sigma=1, epsilon=1.4)
# Out:
# np.float64(9.078857688780786)

# %%
width = 11.3
min_size = 0.9871
num_boxes = width//min_size
box_width = min_size + (width%min_size)/num_boxes

# %%
np.arange(start=0, stop=width, step=box_width)
# Out:
# array([ 0.        ,  1.02727273,  2.05454545,  3.08181818,  4.10909091,
#         5.13636364,  6.16363636,  7.19090909,  8.21818182,  9.24545455,
#        10.27272727])

# %%
np.random.rand(3)
# Out:
# array([0.65506062, 0.70018987, 0.97841051])
