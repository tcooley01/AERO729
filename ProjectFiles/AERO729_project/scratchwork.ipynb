# %%
from particle import Particle
import numpy as np
from simulationenv import SimulationEnviroment
import matplotlib.pyplot as plt

# %% [markdown]
# Create simulation enviroment

# %%
s = SimulationEnviroment(
    particles=100,
    env_height=1,
    env_width=1,
    tolerance=1e-3,
    sigma=0.01,
    epsilon=0.01
)

# %% [markdown]
# Run gradient descent to find intial configuration

# %%
s.steepest_descent_initialization()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 s.steepest_descent_initialization()
#
# File ~/Documents/Dev/AERO729/ProjectFiles/AERO729_project/simulationenv.py:190, in SimulationEnviroment.steepest_descent_initialization(self, gamma, num_iters)
#     186 for _ in range(num_iters):
#     188     for prtcl in self.particle_list:
# --> 190         self.calculate_particle_force(
#     191             particle=prtcl
#     192         )
#     194     for prtcl in self.particle_list:
#     196         old_pos = prtcl.position
#
# File ~/Documents/Dev/AERO729/ProjectFiles/AERO729_project/simulationenv.py:252, in SimulationEnviroment.calculate_particle_force(self, particle)
#     249     if particle is othr_prtcl:
#     250         continue
# --> 252     force = particle.calculate_force(
#     253         other_pos=othr_prtcl.position
#     254     )
#     256     particle.increment_force(
#     257         new_force=force
#     258     )
#     260 # Now we go through and calculate for each adjacent grid space
#     261
#     262 # right no vertical movement
#
# File ~/Documents/Dev/AERO729/ProjectFiles/AERO729_project/particle.py:106, in Particle.calculate_force(self, other_pos)
#     103 dist = np.linalg.norm(self.pos - other_pos)
#     105 if dist == 0:
# --> 106     raise Exception(f'got zero')
#     108 if dist > np.sqrt(4*(self.grid_width**2) + 4*(self.grid_height**2)):
#     109
#     110     # case I am in the far left
#     111     if self.grid_pos[0] == 0:
#
# Exception: got zero

# %%
s.run_sim(
    duration=10,
    del_t=1e-4
)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 s.run_sim(
#       2     duration=10,
#       3     del_t=1e-4
#       4 )
#
# File ~/Documents/Dev/AERO729/ProjectFiles/AERO729_project/simulationenv.py:423, in SimulationEnviroment.run_sim(self, duration, del_t)
#     418 for i in range(num_steps):
#     419
#     420     # calculate force acting on each particle
#     421     for prtcl in self.particle_list:
# --> 423         self.calculate_particle_force(
#     424             particle=prtcl
#     425         )
#     428     # step each particle and figure out its grid position
#     429     for prtcl in self.particle_list:
#
# File ~/Documents/Dev/AERO729/ProjectFiles/AERO729_project/simulationenv.py:252, in SimulationEnviroment.calculate_particle_force(self, particle)
#     249     if particle is othr_prtcl:
#     250         continue
# --> 252     force = particle.calculate_force(
#     253         other_pos=othr_prtcl.position
#     254     )
#     256     particle.increment_force(
#     257         new_force=force
#     258     )
#     260 # Now we go through and calculate for each adjacent grid space
#     261
#     262 # right no vertical movement
#
# File ~/Documents/Dev/AERO729/ProjectFiles/AERO729_project/particle.py:106, in Particle.calculate_force(self, other_pos)
#     103 dist = np.linalg.norm(self.pos - other_pos)
#     105 if dist == 0:
# --> 106     raise Exception(f'got zero')
#     108 if dist > np.sqrt(4*(self.grid_width**2) + 4*(self.grid_height**2)):
#     109
#     110     # case I am in the far left
#     111     if self.grid_pos[0] == 0:
#
# Exception: got zero

# %%
s1 = s.particle_list[1]
s2 = s.particle_list[2]
s3 = s.particle_list[3]
s4 = s.particle_list[4]
s5 = s.particle_list[5]

# %%
x1, y1 = zip(*s1.trajectory)
x1 = np.array(x1)
y1 = np.array(y1)
x2, y2 = zip(*s2.trajectory)
x2 = np.array(x2)
y2 = np.array(y2)
x3, y3 = zip(*s3.trajectory)
x3 = np.array(x3)
y3 = np.array(y3)
x4, y4 = zip(*s4.trajectory)
x4 = np.array(x4)
y4 = np.array(y4)

# %%
plt.plot(x1, y1)
plt.plot(x2, y2)
#plt.plot(x3, y3)
plt.plot(x4, y4)

# %%
poistions = [particle.position for particle in s.particle_list]

# %%
x_1, y_1 = zip(*poistions)
x_1 = np.array(x_1)
y_1 = np.array(y_1)

plt.scatter(x_1, y_1, s=0.5)
