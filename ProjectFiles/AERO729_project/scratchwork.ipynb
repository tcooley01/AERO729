# %%
from particle import Particle
import numpy as np
from simulationenv import SimulationEnviroment
import matplotlib.pyplot as plt

# %%
s = SimulationEnviroment(
    particles=5000,
    env_height=1,
    env_width=1,
    tolerance=1e-3,
    sigma=1e-4,
    epsilon=0.3
)

# %%
s.run_sim(
    duration=1,
    del_t=0.001
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 s.run_sim(
#       2     duration=1,
#       3     del_t=0.001
#       4 )
#
# File ~/Studies/AERO729/AERO729/ProjectFiles/AERO729_project/simulationenv.py:364, in SimulationEnviroment.run_sim(self, duration, del_t)
#     355 grid_key = (
#     356     int(prtcl.grid_position[0]),
#     357     int(prtcl.grid_position[1])
#     358     )
#     360 _ = prtcl.step(
#     361     del_t=del_t
#     362 )
# --> 364 x_ind = int((prtcl.position[0]%self.width)//self.sub_width)
#     365 y_ind = int((prtcl.position[1]%self.height)//self.sub_height)
#     367 new_grid_idx = np.array([x_ind, y_ind])
#
# ValueError: cannot convert float NaN to integer

# %%
sample_particle = s.particle_list[121]
sample_particle.trajectory
# Out:
# [array([0.03988926, 0.8020084 ]),
#  array([0.04283088, 0.79245085]),
#  array([0.0457725 , 0.78289329]),
#  array([0.04871413, 0.77333574]),
#  array([0.05165575, 0.76377818]),
#  array([0.05459738, 0.75422063]),
#  array([0.057539  , 0.74466307]),
#  array([0.06048063, 0.73510552]),
#  array([0.06342225, 0.72554796]),
#  array([0.06636387, 0.71599041]),
#  array([0.0693055 , 0.70643286]),
#  array([0.07224712, 0.6968753 ]),
#  array([0.07518875, 0.68731775]),
#  array([0.07813037, 0.67776019]),
#  array([0.08107199, 0.66820264]),
#  array([0.08401362, 0.65864508]),
#  array([0.08695524, 0.64908753]),
#  array([0.08989687, 0.63952997]),
#  array([0.09283849, 0.62997242]),
#  array([0.09578012, 0.62041487]),
#  array([0.09872174, 0.61085731]),
#  array([0.10166336, 0.60129976]),
#  array([0.10460499, 0.5917422 ]),
#  array([0.10754661, 0.58218465]),
#  array([0.11048824, 0.57262709]),
#  array([0.11342986, 0.56306954]),
#  array([0.11637148, 0.55351198]),
#  array([0.11931311, 0.54395443]),
#  array([0.12225473, 0.53439688]),
#  array([0.12519636, 0.52483932]),
#  array([0.12813798, 0.51528177]),
#  array([0.13107961, 0.50572421]),
#  array([0.13402123, 0.49616666]),
#  array([0.13696285, 0.4866091 ]),
#  array([0.13990448, 0.47705155]),
#  array([0.1428461 , 0.46749399]),
#  array([0.14578773, 0.45793644]),
#  array([0.14872935, 0.44837889]),
#  array([0.15167098, 0.43882133]),
#  array([0.1546126 , 0.42926378]),
#  array([0.15755422, 0.41970622]),
#  array([0.16049585, 0.41014867]),
#  array([0.16343747, 0.40059111]),
#  array([0.1663791 , 0.39103356]),
#  array([0.16932072, 0.381476  ]),
#  array([0.17226234, 0.37191845]),
#  array([0.17520397, 0.3623609 ]),
#  array([0.17814559, 0.35280334]),
#  array([0.18108722, 0.34324579]),
#  array([0.18402884, 0.33368823]),
#  array([0.18697047, 0.32413068]),
#  array([0.18991209, 0.31457312]),
#  array([0.19285371, 0.30501557]),
#  array([0.19579534, 0.29545801]),
#  array([0.19873696, 0.28590046]),
#  array([0.20167859, 0.27634291]),
#  array([0.20462021, 0.26678535]),
#  array([0.20756184, 0.2572278 ]),
#  array([0.21050346, 0.24767024]),
#  array([0.21344508, 0.23811269]),
#  array([0.21638671, 0.22855513]),
#  array([0.21932833, 0.21899758]),
#  array([0.22226996, 0.20944002]),
#  array([0.22521158, 0.19988247]),
#  array([0.2281532 , 0.19032492]),
#  array([0.23109483, 0.18076736]),
#  array([0.23403645, 0.17120981]),
#  array([0.23697808, 0.16165225]),
#  array([0.2399197, 0.1520947]),
#  array([0.24286133, 0.14253714]),
#  array([0.24580295, 0.13297959]),
#  array([0.24874457, 0.12342203]),
#  array([0.2516862 , 0.11386448]),
#  array([0.25462782, 0.10430693]),
#  array([0.06970852, 0.3412591 ]),
#  array([0.88478922, 0.57821128]),
#  array([0.69986992, 0.81516345]),
#  array([0.51495062, 0.05211563]),
#  array([0.33003132, 0.2890678 ]),
#  array([0.14511202, 0.52601998]),
#  array([0.96019889, 0.76290621]),
#  array([0.77528576, 0.99979245]),
#  array([0.59037263, 0.23667869]),
#  array([0.40545949, 0.47356492]),
#  array([0.22054636, 0.71045116]),
#  array([0.03563323, 0.9473374 ]),
#  array([0.8507201 , 0.18422363]),
#  array([0.66580697, 0.42110987]),
#  array([0.48089383, 0.65799611]),
#  array([0.2959807 , 0.89488234]),
#  array([0.11106757, 0.13176858]),
#  array([0.92615444, 0.36865482]),
#  array([0.7412413 , 0.60554106]),
#  array([0.55632817, 0.84242729]),
#  array([0.37141504, 0.07931353]),
#  array([0.18650191, 0.31619977]),
#  array([0.00158877, 0.553086  ]),
#  array([0.81667564, 0.78997224]),
#  array([0.63176251, 0.02685848]),
#  array([0.44684938, 0.26374471]),
#  array([0.26193625, 0.50063095])]

# %%
x, y = zip(*sample_particle.trajectory)
x = np.array(x)
y = np.array(y)

# %%
plt.plot(x, y)
